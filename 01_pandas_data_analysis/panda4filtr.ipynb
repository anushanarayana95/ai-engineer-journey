# %%
import pandas as pd

# %%
df = pd.read_csv(
    "/workspaces/ai-engineer-journey/data/survey_results_public.csv",
    engine="python",
    on_bad_lines="skip",
    index_col="ResponseId"
)
schema_df = pd.read_csv("/workspaces/ai-engineer-journey/data/survey_results_schema.csv", index_col="qname")

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
#
#                                                     EdLevel  \
# ResponseId
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                       Associate degree (A.A., A.S., etc.)
# 3              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# ...

# %%
high_salary = (df['ConvertedCompYearly'] > 70000)

# %%
df.loc[high_salary, ['AIAgentExternal', 'ConvertedCompYearly', 'WorkExp']]
# Out:
#                           AIAgentExternal  ConvertedCompYearly  WorkExp
# ResponseId
# 2                                     NaN             104413.0      2.0
# 6                          GitHub Copilot             120000.0     15.0
# 8                                     NaN              72000.0     22.0
# 23                                    NaN              87500.0      7.0
# 26          ChatGPT;GitHub Copilot;Replit             108913.0     37.0
# ...                                   ...                  ...      ...
# 35978                                 NaN              74423.0     29.0
# 35981                                 NaN             130008.0     10.0
# 35987                                 NaN             155521.0     41.0
# 36017                                 NaN              87763.0      6.0
# 36023                                 NaN              78890.0      5.0
#
# [9856 rows x 3 columns]

# %%
filt = df['AIAgentExternal'].str.contains('ChatGPT', na=False)

# %%
filt
# Out:
# ResponseId
# 1         True
# 2        False
# 3         True
# 4         True
# 5        False
#          ...
# 36019    False
# 36020    False
# 36021    False
# 36022     True
# 36023    False
# Name: AIAgentExternal, Length: 36022, dtype: bool

# %%
df.loc[filt]
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 7           I am a developer by profession  25-34 years old
# 11          I am a developer by profession  25-34 years old
# ...                                    ...              ...
# 36001       I am a developer by profession  35-44 years old
# 36005       I am a developer by profession  45-54 years old
# 36014                I am learning to code  35-44 years old
# 36016       I am a developer by profession  45-54 years old
# 36022       I am a developer by profession  25-34 years old
#
#                                                       EdLevel  \
# ResponseId
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...
