# %%
import pandas as pd

# %%
df = pd.read_csv(
    "/workspaces/ai-engineer-journey/data/survey_results_public.csv",
    engine="python",
    on_bad_lines="skip", index_col="ResponseId"
)
schema_df = pd.read_csv("/workspaces/ai-engineer-journey/data/survey_results_schema.csv", index_col="qname")

# %%
df
# Out:
#                                 MainBranch              Age  \
# ResponseId
# 1           I am a developer by profession  25-34 years old
# 2           I am a developer by profession  25-34 years old
# 3           I am a developer by profession  35-44 years old
# 4           I am a developer by profession  35-44 years old
# 5           I am a developer by profession  35-44 years old
# ...                                    ...              ...
# 36019       I am a developer by profession  25-34 years old
# 36020       I am a developer by profession  35-44 years old
# 36021       I am a developer by profession  55-64 years old
# 36022       I am a developer by profession  25-34 years old
# 36023       I am a developer by profession  25-34 years old
#
#                                                       EdLevel  \
# ResponseId
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                         Associate degree (A.A., A.S., etc.)
# 3                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                       ...
# 36019            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 36020         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 36021       Secondary school (e.g. American high school, G...
# 36022            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 36023            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# ResponseId
# 1                                                    Employed
# 2                                                    Employed
# 3           Independent contractor, freelancer, or self-em...
# 4                                                    Employed
# 5           Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 36019                                            Not employed
# 36020                                                Employed
# 36021       Independent contractor, freelancer, or self-em...
# 36022                                                Employed
# 36023                                                Employed
#
#                                              EmploymentAddl  WorkExp  \
# ResponseId
# 1           Caring for dependents (children, elderly, etc.)      8.0
# 2                                                       NaN      2.0
# 3                                         None of the above     10.0
# 4                                         None of the above      4.0
# 5           Caring for dependents (children, elderly, etc.)     21.0
# ...                                                     ...      ...
# 36019                                     None of the above      NaN
# 36020                                     None of the above     13.0
# 36021       Caring for dependents (children, elderly, etc.)     35.0
# 36022                                     None of the above      7.0
# 36023                                     None of the above      5.0
#
#                                               LearnCodeChoose  \
# ResponseId
# 1           Yes, I am not new to coding but am learning ne...
# 2           Yes, I am not new to coding but am learning ne...
# 3           Yes, I am not new to coding but am learning ne...
# 4           Yes, I am not new to coding but am learning ne...
# 5           No, I am not new to coding and did not learn n...
# ...                                                       ...
# 36019          Yes, I am new to coding or currently a student
# 36020       No, I am not new to coding and did not learn n...
# 36021       Yes, I am not new to coding but am learning ne...
# 36022       Yes, I am not new to coding but am learning ne...
# 36023       Yes, I am not new to coding but am learning ne...
#
#                                                     LearnCode  \
# ResponseId
# 1           Online Courses or Certification (includes all ...
# 2           Online Courses or Certification (includes all ...
# 3           Online Courses or Certification (includes all ...
# 4           Other online resources (e.g. standard search, ...
# 5                                                         NaN
# ...                                                       ...
# 36019       Videos (not associated with specific online co...
# 36020                                                     NaN
# 36021       Technical documentation (is generated for/by t...
# 36022       Online Courses or Certification (includes all ...
# 36023       Online Courses or Certification (includes all ...
#
#                                                   LearnCodeAI  \
# ResponseId
# 1           Yes, I learned how to use AI-enabled tools for...
# 2           Yes, I learned how to use AI-enabled tools for...
# 3           Yes, I learned how to use AI-enabled tools for...
# 4           Yes, I learned how to use AI-enabled tools for...
# 5           Yes, I learned how to use AI-enabled tools for...
# ...                                                       ...
# 36019       Yes, I learned how to use AI-enabled tools req...
# 36020       No, I didn't spend time learning in the past year
# 36021       No, I learned something that was not related t...
# 36022       Yes, I learned how to use AI-enabled tools req...
# 36023       Yes, I learned how to use AI-enabled tools for...
#
#                                                    AILearnHow  YearsCode  \
# ResponseId
# 1                         AI CodeGen tools or AI-enabled apps       14.0
# 2                         AI CodeGen tools or AI-enabled apps       10.0
# 3           AI CodeGen tools or AI-enabled apps;Technical ...       12.0
# 4           AI CodeGen tools or AI-enabled apps;Videos (no...        5.0
# 5           Technical documentation (is generated for/by t...       22.0
# ...                                                       ...        ...
# 36019       Online Courses or Certification (includes all ...        NaN
# 36020                                                     NaN       22.0
# 36021                                                     NaN       40.0
# 36022       Online Courses or Certification (includes all ...       12.0
# 36023       AI CodeGen tools or AI-enabled apps;Other onli...        5.0
#
#                                     DevType                   OrgSize  \
# ResponseId
# 1                         Developer, mobile        20 to 99 employees
# 2                       Developer, back-end      500 to 999 employees
# 3                      Developer, front-end                       NaN
# 4                       Developer, back-end  10,000 or more employees
# 5                       Engineering manager                       NaN
# ...                                     ...                       ...
# 36019                                   NaN                       NaN
# 36020                   Developer, back-end        20 to 99 employees
# 36021                 Developer, full-stack                       NaN
# 36022                 Developer, full-stack  10,000 or more employees
# 36023       DevOps engineer or professional      100 to 499 employees
#
#                             ICorPM  \
# ResponseId
# 1                   People manager
# 2           Individual contributor
# 3                              NaN
# 4           Individual contributor
# 5                              NaN
# ...                            ...
# 36019                          NaN
# 36020       Individual contributor
# 36021                          NaN
# 36022       Individual contributor
# 36023       Individual contributor
#
#                                                    RemoteWork  \
# ResponseId
# 1                                                      Remote
# 2           Hybrid (some in-person, leans heavy to flexibi...
# 3                                                         NaN
# 4                                                      Remote
# 5                                                         NaN
# ...                                                       ...
# 36019                                                     NaN
# 36020          Hybrid (some remote, leans heavy to in-person)
# 36021                                                     NaN
# 36022          Hybrid (some remote, leans heavy to in-person)
# 36023       Your choice (very flexible, you can come in wh...
#
#                                             PurchaseInfluence  \
# ResponseId
# 1           Yes, I influenced the purchase of a substantia...
# 2                                                          No
# 3                                                          No
# 4                                                          No
# 5           Yes, I endorsed a tool that was open-source an...
# ...                                                       ...
# 36019                                                     NaN
# 36020                                                      No
# 36021                                                      No
# 36022       Yes, I influenced the purchase of a tool that ...
# 36023                                                      No
#
#             TechEndorseIntro  TechEndorse_1  TechEndorse_2  TechEndorse_3  \
# ResponseId
# 1                       Work           10.0            7.0            9.0
# 2           Personal Project           13.0            1.0            2.0
# 3                       Work           12.0            2.0            3.0
# 4           Personal Project            2.0           12.0            6.0
# 5                       Work            6.0            3.0            1.0
# ...                      ...            ...            ...            ...
# 36019                    NaN            NaN            NaN            NaN
# 36020                   Work            7.0            3.0            1.0
# 36021                   Work            9.0            3.0            4.0
# 36022                   Work            6.0            2.0            4.0
# 36023                   Work            9.0            4.0            3.0
#
#             TechEndorse_4  TechEndorse_5  TechEndorse_6  TechEndorse_7  \
# ResponseId
# 1                     6.0            3.0           11.0           12.0
# 2                     9.0            4.0            3.0           12.0
# 3                     7.0            5.0           10.0           13.0
# 4                     5.0           13.0            3.0            8.0
# 5                     9.0           10.0            8.0            7.0
# ...                   ...            ...            ...            ...
# 36019                 NaN            NaN            NaN            NaN
# 36020                 4.0            8.0            6.0            9.0
# 36021                 6.0            5.0            1.0            8.0
# 36022                 5.0            7.0            8.0            9.0
# 36023                 8.0            2.0            1.0            7.0
#
#             TechEndorse_8  TechEndorse_9  TechEndorse_13 TechEndorse_13_TEXT  \
# ResponseId
# 1                     1.0            8.0            14.0                 NaN
# 2                     5.0            7.0            14.0                 NaN
# 3                     1.0            4.0            14.0                 NaN
# 4                    11.0            7.0            14.0                 NaN
# 5                     4.0            2.0            14.0                 NaN
# ...                   ...            ...             ...                 ...
# 36019                 NaN            NaN             NaN                 NaN
# 36020                 2.0            5.0            10.0                 NaN
# 36021                 2.0            7.0            10.0                 NaN
# 36022                 3.0            1.0            10.0                 NaN
# 36023                 5.0            6.0            10.0                 NaN
#
#             TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# ResponseId
# 1                   15.0           7.0           8.0          12.0
# 2                   14.0           1.0          13.0          10.0
# 3                    8.0           1.0           2.0          12.0
# 4                   10.0           5.0           8.0           4.0
# 5                    7.0          13.0           3.0           9.0
# ...                  ...           ...           ...           ...
# 36019                NaN           NaN           NaN           NaN
# 36020                9.0           2.0           3.0           6.0
# 36021                8.0           9.0           7.0           3.0
# 36022                9.0           7.0           6.0           3.0
# 36023                9.0           4.0           6.0           5.0
#
#             TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  \
# ResponseId
# 1                   11.0           1.0            6.0           13.0
# 2                    9.0           3.0            4.0            2.0
# 3                   13.0           3.0            9.0            4.0
# 4                   13.0          12.0            2.0            7.0
# 5                   12.0           6.0            1.0            8.0
# ...                  ...           ...            ...            ...
# 36019                NaN           NaN            NaN            NaN
# 36020                4.0           7.0            1.0            5.0
# 36021                4.0           2.0            5.0            6.0
# 36022                4.0           2.0            5.0            8.0
# 36023                2.0           3.0            1.0            7.0
#
#             TechOppose_16  TechOppose_15 TechOppose_15_TEXT  \
# ResponseId
# 1                     3.0           16.0                NaN
# 2                     5.0           15.0                NaN
# 3                    11.0           15.0                NaN
# 4                     1.0           15.0                NaN
# 5                    14.0           15.0                NaN
# ...                   ...            ...                ...
# 36019                 NaN            NaN                NaN
# 36020                 8.0           10.0                NaN
# 36021                 1.0           10.0                NaN
# 36022                 1.0           10.0                NaN
# 36023                 8.0           10.0                NaN
#
#                                         Industry  JobSatPoints_1  \
# ResponseId
# 1                                        Fintech             3.0
# 2                   Retail and Consumer Services            10.0
# 3                           Software Development             9.0
# 4                   Retail and Consumer Services             1.0
# 5                           Software Development             9.0
# ...                                          ...             ...
# 36019                                        NaN             NaN
# 36020            Transportation, or Supply Chain             2.0
# 36021                       Software Development             6.0
# 36022                              Manufacturing             3.0
# 36023       Computer Systems Design and Services             2.0
#
#             JobSatPoints_2  ...  SO_Actions_10  SO_Actions_15  \
# ResponseId                  ...
# 1                      1.0  ...           11.0           15.0
# 2                      8.0  ...           11.0           15.0
# 3                      6.0  ...           11.0           15.0
# 4                      2.0  ...           11.0           15.0
# 5                      4.0  ...           12.0           15.0
# ...                    ...  ...            ...            ...
# 36019                  NaN  ...            NaN            NaN
# 36020                  1.0  ...            9.0           10.0
# 36021                  3.0  ...            NaN            NaN
# 36022                  4.0  ...            5.0           10.0
# 36023                  3.0  ...            9.0           10.0
#
#             SO_Actions_15_TEXT           SOComm  \
# ResponseId
# 1                          NaN          Neutral
# 2                          NaN    Yes, somewhat
# 3                          NaN          Neutral
# 4                          NaN          Neutral
# 5                          NaN   No, not really
# ...                        ...              ...
# 36019                      NaN              NaN
# 36020                      NaN          Neutral
# 36021                      NaN              NaN
# 36022                      NaN  Yes, definitely
# 36023                      NaN    Yes, somewhat
#
#                                     SOFriction  \
# ResponseId
# 1                         Rarely, almost never
# 2                       About half of the time
# 3                       About half of the time
# 4                         Rarely, almost never
# 5                         Rarely, almost never
# ...                                        ...
# 36019                                      NaN
# 36020       I don't use AI or AI-enabled tools
# 36021                                      NaN
# 36022               Less than half of the time
# 36023                   About half of the time
#
#                                                AISelect            AISent  \
# ResponseId
# 1           Yes, I use AI tools monthly or infrequently       Indifferent
# 2                            Yes, I use AI tools weekly       Indifferent
# 3                             Yes, I use AI tools daily         Favorable
# 4                            Yes, I use AI tools weekly         Favorable
# 5                            Yes, I use AI tools weekly         Favorable
# ...                                                 ...               ...
# 36019                                               NaN               NaN
# 36020                            No, but I plan to soon       Unfavorable
# 36021                           No, and I don't plan to  Very unfavorable
# 36022                         Yes, I use AI tools daily    Very favorable
# 36023                         Yes, I use AI tools daily         Favorable
#
#                                  AIAcc  \
# ResponseId
# 1           Neither trust nor distrust
# 2           Neither trust nor distrust
# 3                       Somewhat trust
# 4                       Somewhat trust
# 5           Neither trust nor distrust
# ...                                ...
# 36019                              NaN
# 36020                Somewhat distrust
# 36021                  Highly distrust
# 36022                  Highly distrust
# 36023                Somewhat distrust
#
#                                                     AIComplex  \
# ResponseId
# 1                               Bad at handling complex tasks
# 2                               Bad at handling complex tasks
# 3               Neither good or bad at handling complex tasks
# 4                               Bad at handling complex tasks
# 5               Good, but not great at handling complex tasks
# ...                                                       ...
# 36019                                                     NaN
# 36020       I don't use AI tools for complex tasks / I don...
# 36021       I don't use AI tools for complex tasks / I don...
# 36022                     Very poor at handling complex tasks
# 36023                     Very poor at handling complex tasks
#
#                                  AIToolCurrently partially AI  \
# ResponseId
# 1           Learning about a codebase;Writing code;Search ...
# 2                       Learning new concepts or technologies
# 3           Documenting code;Debugging or fixing code;Test...
# 4                                                         NaN
# 5           Learning about a codebase;Writing code;Debuggi...
# ...                                                       ...
# 36019                                                     NaN
# 36020                                                     NaN
# 36021                                                     NaN
# 36022       Learning about a codebase;Debugging or fixing ...
# 36023       Learning about a codebase;Writing code;Documen...
#
#                      AIToolDon't plan to use AI for this task  \
# ResponseId
# 1           Project planning;Deployment and monitoring;Lea...
# 2           Learning about a codebase;Project planning;Com...
# 3                                                         NaN
# 4           Project planning;Documenting code;Testing code...
# 5           Project planning;Documenting code;Testing code...
# ...                                                       ...
# 36019                                                     NaN
# 36020       Learning about a codebase;Project planning;Wri...
# 36021       Learning about a codebase;Project planning;Wri...
# 36022       Project planning;Documenting code;Committing a...
# 36023       Project planning;Testing code;Deployment and m...
#
#                                AIToolPlan to partially use AI  \
# ResponseId
# 1           Documenting code;Debugging or fixing code;Test...
# 2           Writing code;Documenting code;Debugging or fix...
# 3           Project planning;Committing and reviewing code...
# 4           Learning about a codebase;Writing code;Debuggi...
# 5                        Generating content or synthetic data
# ...                                                       ...
# 36019                                                     NaN
# 36020                                                     NaN
# 36021                                      Search for answers
# 36022                                            Writing code
# 36023                                                     NaN
#
#                                   AIToolPlan to mostly use AI  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           Learning about a codebase;Writing code;Generat...
# 4           Search for answers;Generating content or synth...
# 5                                                         NaN
# ...                                                       ...
# 36019                                                     NaN
# 36020                                                     NaN
# 36021                                                     NaN
# 36022       Testing code;Deployment and monitoring;Search ...
# 36023       Debugging or fixing code;Committing and review...
#
#            AIToolCurrently mostly AI  \
# ResponseId
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 5                                NaN
# ...                              ...
# 36019                            NaN
# 36020                            NaN
# 36021                            NaN
# 36022                            NaN
# 36023             Search for answers
#
#                                                 AIFrustration AIExplain  \
# ResponseId
# 1           AI solutions that are almost right, but not quite        No
# 2           AI solutions that are almost right, but not qu...        No
# 3           AI solutions that are almost right, but not qu...        No
# 4           AI solutions that are almost right, but not qu...        NO
# 5           AI solutions that are almost right, but not quite    partly
# ...                                                       ...       ...
# 36019                                                     NaN       NaN
# 36020                          I don’t use AI tools regularly        No
# 36021       AI solutions that are almost right, but not qu...        no
# 36022       AI solutions that are almost right, but not qu...        No
# 36023       AI solutions that are almost right, but not qu...        no
#
#                                                      AIAgents  \
# ResponseId
# 1           Yes, I use AI agents at work monthly or infreq...
# 2                                     No, and I don't plan to
# 3                         Yes, I use AI agents at work weekly
# 4           Yes, I use AI agents at work monthly or infreq...
# 5                                     No, and I don't plan to
# ...                                                       ...
# 36019                                                     NaN
# 36020                                       No, but I plan to
# 36021                                 No, and I don't plan to
# 36022                      Yes, I use AI agents at work daily
# 36023                                 No, and I don't plan to
#
#                       AIAgentChange          AIAgent_Uses  \
# ResponseId
# 1           Not at all or minimally  Software engineering
# 2           Not at all or minimally                   NaN
# 3                     Yes, somewhat  Software engineering
# 4           Not at all or minimally  Software engineering
# 5            Yes, to a great extent                   NaN
# ...                             ...                   ...
# 36019                           NaN                   NaN
# 36020       Not at all or minimally                   NaN
# 36021       Not at all or minimally                   NaN
# 36022                 Yes, somewhat  Software engineering
# 36023                 Yes, somewhat                   NaN
#
#                             AgentUsesGeneral  \
# ResponseId
# 1                                        NaN
# 2                                        NaN
# 3           Multi-platform search enablement
# 4                        Language processing
# 5                                        NaN
# ...                                      ...
# 36019                                    NaN
# 36020                                    NaN
# 36021                                    NaN
# 36022                                    NaN
# 36023                                    NaN
#
#                                   AIAgentImpactSomewhat agree  \
# ResponseId
# 1           AI agents have increased my productivity.;AI a...
# 2                                                         NaN
# 3           AI agents have increased my productivity.;AI a...
# 4           AI agents have accelerated my learning about n...
# 5                                                         NaN
# ...                                                       ...
# 36019                                                     NaN
# 36020                                                     NaN
# 36021                                                     NaN
# 36022       AI agents have increased my productivity.;AI a...
# 36023                                                     NaN
#
#                                          AIAgentImpactNeutral  \
# ResponseId
# 1           AI agents have helped me automate repetitive t...
# 2                                                         NaN
# 3           AI agents have improved the quality of my code...
# 4           AI agents have increased my productivity.;AI a...
# 5                                                         NaN
# ...                                                       ...
# 36019                                                     NaN
# 36020                                                     NaN
# 36021                                                     NaN
# 36022       AI agents have helped me automate repetitive t...
# 36023                                                     NaN
#
#                                AIAgentImpactSomewhat disagree  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3           AI agents have improved collaboration within m...
# 4           AI agents have helped me automate repetitive t...
# 5                                                         NaN
# ...                                                       ...
# 36019                                                     NaN
# 36020                                                     NaN
# 36021                                                     NaN
# 36022         AI agents have improved the quality of my code.
# 36023                                                     NaN
#
#                                   AIAgentImpactStrongly agree  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 36019                                                     NaN
# 36020                                                     NaN
# 36021                                                     NaN
# 36022       AI agents have helped me solve complex problem...
# 36023                                                     NaN
#
#                                AIAgentImpactStrongly disagree  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 36019                                                     NaN
# 36020                                                     NaN
# 36021                                                     NaN
# 36022       AI agents have reduced the time spent on speci...
# 36023                                                     NaN
#
#                                      AIAgentChallengesNeutral  \
# ResponseId
# 1           I am concerned about the accuracy of the infor...
# 2           It takes significant time and effort to learn ...
# 3           It takes significant time and effort to learn ...
# 4           It takes significant time and effort to learn ...
# 5           Integrating AI agents with my existing tools a...
# ...                                                       ...
# 36019                                                     NaN
# 36020       Integrating AI agents with my existing tools a...
# 36021       I am concerned about the accuracy of the infor...
# 36022                                                     NaN
# 36023       Integrating AI agents with my existing tools a...
#
#                            AIAgentChallengesSomewhat disagree  \
# ResponseId
# 1           Integrating AI agents with my existing tools a...
# 2                                                         NaN
# 3           My company's IT and/or InfoSec teams have stri...
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 36019                                                     NaN
# 36020       It takes significant time and effort to learn ...
# 36021                                                     NaN
# 36022                                                     NaN
# 36023                                                     NaN
#
#                               AIAgentChallengesStrongly agree  \
# ResponseId
# 1           The cost of using certain AI agent platforms i...
# 2           I am concerned about the accuracy of the infor...
# 3                                                         NaN
# 4           I am concerned about the accuracy of the infor...
# 5           I am concerned about the accuracy of the infor...
# ...                                                       ...
# 36019                                                     NaN
# 36020                                                     NaN
# 36021       I have concerns about the security and privacy...
# 36022       The cost of using certain AI agent platforms i...
# 36023       I am concerned about the accuracy of the infor...
#
#                               AIAgentChallengesSomewhat agree  \
# ResponseId
# 1                                                         NaN
# 2           Integrating AI agents with my existing tools a...
# 3           I am concerned about the accuracy of the infor...
# 4           Integrating AI agents with my existing tools a...
# 5           It takes significant time and effort to learn ...
# ...                                                       ...
# 36019                                                     NaN
# 36020       I am concerned about the accuracy of the infor...
# 36021                                                     NaN
# 36022       I am concerned about the accuracy of the infor...
# 36023       It takes significant time and effort to learn ...
#
#                            AIAgentChallengesStrongly disagree  \
# ResponseId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 36019                                                     NaN
# 36020                                                     NaN
# 36021       It takes significant time and effort to learn ...
# 36022       Integrating AI agents with my existing tools a...
# 36023                                                     NaN
#
#            AIAgentKnowledge AIAgentKnowWrite AIAgentOrchestration  \
# ResponseId
# 1                       NaN              NaN            Vertex AI
# 2                       NaN              NaN                  NaN
# 3                     Redis              NaN                  NaN
# 4                       NaN              NaN                  NaN
# 5                       NaN              NaN                  NaN
# ...                     ...              ...                  ...
# 36019                   NaN              NaN                  NaN
# 36020                   NaN              NaN                  NaN
# 36021                   NaN              NaN                  NaN
# 36022                   NaN              NaN                  NaN
# 36023                   NaN              NaN                  NaN
#
#            AIAgentOrchWrite AIAgentObserveSecure AIAgentObsWrite  \
# ResponseId
# 1                       NaN                  NaN             NaN
# 2                       NaN                  NaN             NaN
# 3                       NaN                  NaN             NaN
# 4                       NaN                  NaN             NaN
# 5                       NaN                  NaN             NaN
# ...                     ...                  ...             ...
# 36019                   NaN                  NaN             NaN
# 36020                   NaN                  NaN             NaN
# 36021                   NaN                  NaN             NaN
# 36022                   NaN                  NaN             NaN
# 36023                   NaN                  NaN             NaN
#
#                                              AIAgentExternal AIAgentExtWrite  \
# ResponseId
# 1                                                    ChatGPT             NaN
# 2                                                        NaN             NaN
# 3           ChatGPT;Claude Code;GitHub Copilot;Google Gemini             NaN
# 4                                        ChatGPT;Claude Code             NaN
# 5                                                        NaN             NaN
# ...                                                      ...             ...
# 36019                                                    NaN             NaN
# 36020                                                    NaN             NaN
# 36021                                                    NaN             NaN
# 36022                                 ChatGPT;GitHub Copilot             NaN
# 36023                                                    NaN             NaN
#
#                                                       AIHuman  \
# ResponseId
# 1                             When I don’t trust AI’s answers
# 2           When I don’t trust AI’s answers;When I want to...
# 3           When I don’t trust AI’s answers;When I want to...
# 4           When I don’t trust AI’s answers;When I want to...
# 5                             When I don’t trust AI’s answers
# ...                                                       ...
# 36019                                                     NaN
# 36020       When I don’t trust AI’s answers;When I want to...
# 36021               When I want to fully understand something
# 36022       When I don’t trust AI’s answers;When I have et...
# 36023       When I don’t trust AI’s answers;When I want to...
#
#                                                        AIOpen  \
# ResponseId
# 1                       Troubleshooting, profiling, debugging
# 2                                   All skills. AI is a flop.
# 3           Understand how things actually work, problem s...
# 4                                                         NaN
# 5           critical thinking, the skill to define the tas...
# ...                                                       ...
# 36019                                                     NaN
# 36020                                            Common sense
# 36021                                             inteligence
# 36022       Full Stack Web Development - developer which u...
# 36023         critical thinking, problem solving, kiss, yagni
#
#            ConvertedCompYearly JobSat
# ResponseId
# 1                      61256.0   10.0
# 2                     104413.0    9.0
# 3                      53061.0    8.0
# 4                      36197.0    6.0
# 5                      60000.0    7.0
# ...                        ...    ...
# 36019                      NaN    NaN
# 36020                  58007.0    8.0
# 36021                  69609.0    9.0
# 36022                      NaN    6.0
# 36023                  78890.0    7.0
#
# [36022 rows x 171 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 36022 entries, 1 to 36023
# Columns: 171 entries, MainBranch to JobSat
# dtypes: float64(52), str(119)
# memory usage: 47.3 MB

# %%
df.shape
# Out:
# (36022, 171)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='str', length=172)

# %%
df['EdLevel'].value_counts()
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          14816
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        9353
# Some college/university study without earning a degree                                 4513
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     2722
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         1925
# Associate degree (A.A., A.S., etc.)                                                    1114
# Other (please specify):                                                                 470
# Primary/elementary school                                                               411
# Name: count, dtype: int64

# %%
df.loc[0:2, 'EdLevel':'Employment']
# Out:
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# 4  Independent contractor, freelancer, or self-em...
#
#                                     EmploymentAddl  WorkExp  \
# 0  Caring for dependents (children, elderly, etc.)      8.0
# 1                                              NaN      2.0
# 2                                None of the above     10.0
# 3                                None of the above      4.0
# 4  Caring for dependents (children, elderly, etc.)     21.0
#
#                                      LearnCodeChoose  \
# 0  Yes, I am not new to coding but am learning ne...
# 1  Yes, I am not new to coding but am learning ne...
# 2  Yes, I am not new to coding but am learning ne...
# 3  Yes, I am not new to coding but am learning ne...
# 4  No, I am not new to coding and did not learn n...
#
#                                            LearnCode  \
# 0  Online Courses or Certification (includes all ...
# 1  Online Courses or Certification (includes all ...
# 2  Online Courses or Certification (includes all ...
# 3  Other online resources (e.g. standard search, ...
# 4                                                NaN
#
#                                          LearnCodeAI  \
# 0  Yes, I learned how to use AI-enabled tools for...
# 1  Yes, I learned how to use AI-enabled tools for...
# 2  Yes, I learned how to use AI-enabled tools for...
# 3  Yes, I learned how to use AI-enabled tools for...
# 4  Yes, I learned how to use AI-enabled tools for...
#
#                                           AILearnHow  YearsCode  \
# 0                AI CodeGen tools or AI-enabled apps       14.0
# 1                AI CodeGen tools or AI-enabled apps       10.0
# 2  AI CodeGen tools or AI-enabled apps;Technical ...       12.0
# 3  AI CodeGen tools or AI-enabled apps;Videos (no...        5.0
# 4  Technical documentation (is generated for/by t...       22.0
#
#                 DevType                   OrgSize                  ICorPM  \
# 0     Developer, mobile        20 to 99 employees          People manager
# 1   Developer, back-end      500 to 999 employees  Individual contributor
# 2  Developer, front-end                       NaN                     NaN
# 3   Developer, back-end  10,000 or more employees  Individual contributor
# 4   Engineering manager                       NaN                     NaN
#
#                                           RemoteWork  \
# 0                                             Remote
# 1  Hybrid (some in-person, leans heavy to flexibi...
# 2                                                NaN
# 3                                             Remote
# 4                                                NaN
#
#                                    PurchaseInfluence  TechEndorseIntro  \
# 0  Yes, I influenced the purchase of a substantia...              Work
# 1                                                 No  Personal Project
# 2                                                 No              Work
# 3                                                 No  Personal Project
# 4  Yes, I endorsed a tool that was open-source an...              Work
#
#    TechEndorse_1  TechEndorse_2  TechEndorse_3  TechEndorse_4  TechEndorse_5  \
# 0           10.0            7.0            9.0            6.0            3.0
# 1           13.0            1.0            2.0            9.0            4.0
# 2           12.0            2.0            3.0            7.0            5.0
# 3            2.0           12.0            6.0            5.0           13.0
# 4            6.0            3.0            1.0            9.0           10.0
#
#    TechEndorse_6  TechEndorse_7  TechEndorse_8  TechEndorse_9  TechEndorse_13  \
# 0           11.0           12.0            1.0            8.0            14.0
# 1            3.0           12.0            5.0            7.0            14.0
# 2           10.0           13.0            1.0            4.0            14.0
# 3            3.0            8.0           11.0            7.0            14.0
# 4            8.0            7.0            4.0            2.0            14.0
#
#   TechEndorse_13_TEXT  TechOppose_1  TechOppose_2  TechOppose_3  TechOppose_5  \
# 0                 NaN          15.0           7.0           8.0          12.0
# 1                 NaN          14.0           1.0          13.0          10.0
# 2                 NaN           8.0           1.0           2.0          12.0
# 3                 NaN          10.0           5.0           8.0           4.0
# 4                 NaN           7.0          13.0           3.0           9.0
#
#    TechOppose_7  TechOppose_9  TechOppose_11  TechOppose_13  TechOppose_16  \
# 0          11.0           1.0            6.0           13.0            3.0
# 1           9.0           3.0            4.0            2.0            5.0
# 2          13.0           3.0            9.0            4.0           11.0
# 3          13.0          12.0            2.0            7.0            1.0
# 4          12.0           6.0            1.0            8.0           14.0
#
#    TechOppose_15 TechOppose_15_TEXT                      Industry  \
# 0           16.0                NaN                       Fintech
# 1           15.0                NaN  Retail and Consumer Services
# 2           15.0                NaN          Software Development
# 3           15.0                NaN  Retail and Consumer Services
# 4           15.0                NaN          Software Development
#
#    JobSatPoints_1  ...  SO_Actions_10  SO_Actions_15  SO_Actions_15_TEXT  \
# 0             3.0  ...           11.0           15.0                 NaN
# 1            10.0  ...           11.0           15.0                 NaN
# 2             9.0  ...           11.0           15.0                 NaN
# 3             1.0  ...           11.0           15.0                 NaN
# 4             9.0  ...           12.0           15.0                 NaN
#
#            SOComm              SOFriction  \
# 0         Neutral    Rarely, almost never
# 1   Yes, somewhat  About half of the time
# 2         Neutral  About half of the time
# 3         Neutral    Rarely, almost never
# 4  No, not really    Rarely, almost never
#
#                                       AISelect       AISent  \
# 0  Yes, I use AI tools monthly or infrequently  Indifferent
# 1                   Yes, I use AI tools weekly  Indifferent
# 2                    Yes, I use AI tools daily    Favorable
# 3                   Yes, I use AI tools weekly    Favorable
# 4                   Yes, I use AI tools weekly    Favorable
#
#                         AIAcc                                      AIComplex  \
# 0  Neither trust nor distrust                  Bad at handling complex tasks
# 1  Neither trust nor distrust                  Bad at handling complex tasks
# 2              Somewhat trust  Neither good or bad at handling complex tasks
# 3              Somewhat trust                  Bad at handling complex tasks
# 4  Neither trust nor distrust  Good, but not great at handling complex tasks
#
#                         AIToolCurrently partially AI  \
# 0  Learning about a codebase;Writing code;Search ...
# 1              Learning new concepts or technologies
# 2  Documenting code;Debugging or fixing code;Test...
# 3                                                NaN
# 4  Learning about a codebase;Writing code;Debuggi...
#
#             AIToolDon't plan to use AI for this task  \
# 0  Project planning;Deployment and monitoring;Lea...
# 1  Learning about a codebase;Project planning;Com...
# 2                                                NaN
# 3  Project planning;Documenting code;Testing code...
# 4  Project planning;Documenting code;Testing code...
#
#                       AIToolPlan to partially use AI  \
# 0  Documenting code;Debugging or fixing code;Test...
# 1  Writing code;Documenting code;Debugging or fix...
# 2  Project planning;Committing and reviewing code...
# 3  Learning about a codebase;Writing code;Debuggi...
# 4               Generating content or synthetic data
#
#                          AIToolPlan to mostly use AI  \
# 0                                                NaN
# 1                                                NaN
# 2  Learning about a codebase;Writing code;Generat...
# 3  Search for answers;Generating content or synth...
# 4                                                NaN
#
#    AIToolCurrently mostly AI  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
#                                        AIFrustration AIExplain  \
# 0  AI solutions that are almost right, but not quite        No
# 1  AI solutions that are almost right, but not qu...        No
# 2  AI solutions that are almost right, but not qu...        No
# 3  AI solutions that are almost right, but not qu...        NO
# 4  AI solutions that are almost right, but not quite    partly
#
#                                             AIAgents            AIAgentChange  \
# 0  Yes, I use AI agents at work monthly or infreq...  Not at all or minimally
# 1                            No, and I don't plan to  Not at all or minimally
# 2                Yes, I use AI agents at work weekly            Yes, somewhat
# 3  Yes, I use AI agents at work monthly or infreq...  Not at all or minimally
# 4                            No, and I don't plan to   Yes, to a great extent
#
#            AIAgent_Uses                  AgentUsesGeneral  \
# 0  Software engineering                               NaN
# 1                   NaN                               NaN
# 2  Software engineering  Multi-platform search enablement
# 3  Software engineering               Language processing
# 4                   NaN                               NaN
#
#                          AIAgentImpactSomewhat agree  \
# 0  AI agents have increased my productivity.;AI a...
# 1                                                NaN
# 2  AI agents have increased my productivity.;AI a...
# 3  AI agents have accelerated my learning about n...
# 4                                                NaN
#
#                                 AIAgentImpactNeutral  \
# 0  AI agents have helped me automate repetitive t...
# 1                                                NaN
# 2  AI agents have improved the quality of my code...
# 3  AI agents have increased my productivity.;AI a...
# 4                                                NaN
#
#                       AIAgentImpactSomewhat disagree  \
# 0                                                NaN
# 1                                                NaN
# 2  AI agents have improved collaboration within m...
# 3  AI agents have helped me automate repetitive t...
# 4                                                NaN
#
#   AIAgentImpactStrongly agree AIAgentImpactStrongly disagree  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#                             AIAgentChallengesNeutral  \
# 0  I am concerned about the accuracy of the infor...
# 1  It takes significant time and effort to learn ...
# 2  It takes significant time and effort to learn ...
# 3  It takes significant time and effort to learn ...
# 4  Integrating AI agents with my existing tools a...
#
#                   AIAgentChallengesSomewhat disagree  \
# 0  Integrating AI agents with my existing tools a...
# 1                                                NaN
# 2  My company's IT and/or InfoSec teams have stri...
# 3                                                NaN
# 4                                                NaN
#
#                      AIAgentChallengesStrongly agree  \
# 0  The cost of using certain AI agent platforms i...
# 1  I am concerned about the accuracy of the infor...
# 2                                                NaN
# 3  I am concerned about the accuracy of the infor...
# 4  I am concerned about the accuracy of the infor...
#
#                      AIAgentChallengesSomewhat agree  \
# 0                                                NaN
# 1  Integrating AI agents with my existing tools a...
# 2  I am concerned about the accuracy of the infor...
# 3  Integrating AI agents with my existing tools a...
# 4  It takes significant time and effort to learn ...
#
#   AIAgentChallengesStrongly disagree AIAgentKnowledge AIAgentKnowWrite  \
# 0                                NaN              NaN              NaN
# 1                                NaN              NaN              NaN
# 2                                NaN            Redis              NaN
# 3                                NaN              NaN              NaN
# 4                                NaN              NaN              NaN
#
#   AIAgentOrchestration AIAgentOrchWrite AIAgentObserveSecure AIAgentObsWrite  \
# 0            Vertex AI              NaN                  NaN             NaN
# 1                  NaN              NaN                  NaN             NaN
# 2                  NaN              NaN                  NaN             NaN
# 3                  NaN              NaN                  NaN             NaN
# 4                  NaN              NaN                  NaN             NaN
#
#                                     AIAgentExternal AIAgentExtWrite  \
# 0                                           ChatGPT             NaN
# 1                                               NaN             NaN
# 2  ChatGPT;Claude Code;GitHub Copilot;Google Gemini             NaN
# 3                               ChatGPT;Claude Code             NaN
# 4                                               NaN             NaN
#
#                                              AIHuman  \
# 0                    When I don’t trust AI’s answers
# 1  When I don’t trust AI’s answers;When I want to...
# 2  When I don’t trust AI’s answers;When I want to...
# 3  When I don’t trust AI’s answers;When I want to...
# 4                    When I don’t trust AI’s answers
#
#                                               AIOpen ConvertedCompYearly  \
# 0              Troubleshooting, profiling, debugging             61256.0
# 1                          All skills. AI is a flop.            104413.0
# 2  Understand how things actually work, problem s...             53061.0
# 3                                                NaN             36197.0
# 4  critical thinking, the skill to define the tas...             60000.0
#
#   JobSat
# 0   10.0
# 1    9.0
# 2    8.0
# 3    6.0
# 4    7.0
#
# [5 rows x 172 columns]

# %%
schema_df
# Out:
#                     qid                                           question  \
# qname
# TechEndorse_1     QID18  What attracts you to a technology or causes yo...
# TechEndorse_2     QID18  What attracts you to a technology or causes yo...
# TechEndorse_3     QID18  What attracts you to a technology or causes yo...
# TechEndorse_4     QID18  What attracts you to a technology or causes yo...
# TechEndorse_5     QID18  What attracts you to a technology or causes yo...
# ...                 ...                                                ...
# AIAgentObsWrite  QID103  Was the tool or tools for AI agent observabili...
# AIAgentExternal   QID92  You indicated you use or develop AI agents as ...
# AIAgentExtWrite  QID104  Was the out-of-the-box agents, copilots or ass...
# AIHuman          QID100  In the future, if AI can do most coding tasks,...
# AIOpen            QID93  Looking ahead 3–5 years, what skills do you be...
#
#                 type                                      sub  sq_id
# qname
# TechEndorse_1     RO  AI integration or AI Agent capabilities    1.0
# TechEndorse_2     RO                          Easy-to-use API    2.0
# TechEndorse_3     RO                  Robust and complete API    3.0
# TechEndorse_4     RO     Customizable and manageable codebase    4.0
# TechEndorse_5     RO                   Reputation for quality    5.0
# ...              ...                                      ...    ...
# AIAgentObsWrite   TE                                      NaN    NaN
# AIAgentExternal   MC                                      NaN    NaN
# AIAgentExtWrite   TE                                      NaN    NaN
# AIHuman           MC                                      NaN    NaN
# AIOpen            TE                                      NaN    NaN
#
# [139 rows x 5 columns]

# %%
schema_df.loc['RemoteWork','question']
# Out:
# 'Which best describes your current work situation?'

# %%
schema_df.sort_index(ascending=True)
# Out:
#                       qid                                           question  \
# qname
# AIAcc               QID80  How much do you trust the accuracy of the outp...
# AIAgentChallenges   QID88  To what extent do you agree with the following...
# AIAgentChange       QID83  Have AI tools or AI agents changed how you com...
# AIAgentExtWrite    QID104  Was the out-of-the-box agents, copilots or ass...
# AIAgentExternal     QID92  You indicated you use or develop AI agents as ...
# ...                   ...                                                ...
# WebframeChoice      QID47  Did you work with web frameworks and web techn...
# WebframeHaveEntry   QID58  Were the web frameworks and web technologies y...
# WebframeWantEntry   QID59  Were the web frameworks and web technologies y...
# WorkExp             QID14  How many years of professional work experience...
# YearsCode           QID13  Including any education, how many years have y...
#
#                      type  sub  sq_id
# qname
# AIAcc                  MC  NaN    NaN
# AIAgentChallenges  Matrix  NaN    NaN
# AIAgentChange          MC  NaN    NaN
# AIAgentExtWrite        TE  NaN    NaN
# AIAgentExternal        MC  NaN    NaN
# ...                   ...  ...    ...
# WebframeChoice         MC  NaN    NaN
# WebframeHaveEntry      TE  NaN    NaN
# WebframeWantEntry      TE  NaN    NaN
# WorkExp                TE  NaN    NaN
# YearsCode              TE  NaN    NaN
#
# [139 rows x 5 columns]

# %%
schema_df
# Out:
#                     qid                                           question  \
# qname
# TechEndorse_1     QID18  What attracts you to a technology or causes yo...
# TechEndorse_2     QID18  What attracts you to a technology or causes yo...
# TechEndorse_3     QID18  What attracts you to a technology or causes yo...
# TechEndorse_4     QID18  What attracts you to a technology or causes yo...
# TechEndorse_5     QID18  What attracts you to a technology or causes yo...
# ...                 ...                                                ...
# AIAgentObsWrite  QID103  Was the tool or tools for AI agent observabili...
# AIAgentExternal   QID92  You indicated you use or develop AI agents as ...
# AIAgentExtWrite  QID104  Was the out-of-the-box agents, copilots or ass...
# AIHuman          QID100  In the future, if AI can do most coding tasks,...
# AIOpen            QID93  Looking ahead 3–5 years, what skills do you be...
#
#                 type                                      sub  sq_id
# qname
# TechEndorse_1     RO  AI integration or AI Agent capabilities    1.0
# TechEndorse_2     RO                          Easy-to-use API    2.0
# TechEndorse_3     RO                  Robust and complete API    3.0
# TechEndorse_4     RO     Customizable and manageable codebase    4.0
# TechEndorse_5     RO                   Reputation for quality    5.0
# ...              ...                                      ...    ...
# AIAgentObsWrite   TE                                      NaN    NaN
# AIAgentExternal   MC                                      NaN    NaN
# AIAgentExtWrite   TE                                      NaN    NaN
# AIHuman           MC                                      NaN    NaN
# AIOpen            TE                                      NaN    NaN
#
# [139 rows x 5 columns]
